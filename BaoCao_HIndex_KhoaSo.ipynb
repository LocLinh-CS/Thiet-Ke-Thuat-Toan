# %% [markdown]
# ### H-Index
# 1. **Abstraction: phát biểu lại bài toán chỉ bằng 1 câu**
#     - Cho n và dãy n phần tử, tìm k (0 <= k <= n) sao cho có ít nhất k phần tử trong dãy lớn hơn hoặc bằng k.
# 2. **Pattern Recognition: tên dạng bài toán/kỹ thuật được áp dụng, các đặc điểm nhận dạng**
#     -
# 3. **Algorithm designed: thuật toán để giải quyết bài toán (trình bày bằng mã giả/ lưu đồ)**
#     ![flow_chart_Hidex.png](attachment:flow_chart_Hidex.png)
# 4. **Đánh giá độ phức tạp thuật toán**
#     - Time Complexity: O(n)
#     - Auxiliary Space: O(1)

# %%
n = int(input())
c = [int(x) for x in input().split()]


def find_H_Index(arr, k):
    arr.sort()
    while k > 0:
        if arr[n - k] >= k:
            return k
        k -= 1

    return 0


print(find_H_Index(c, n))
# Out:
# 4
# 1 2 3 4
# 2

# %% [markdown]
# ### Khóa số
# 1. **Abstraction: phát biểu lại bài toán chỉ bằng 1 câu**
#     -
# 2. **Pattern Recognition: tên dạng bài toán/kỹ thuật được áp dụng, các đặc điểm nhận dạng**
#     -
# 3. **Algorithm designed: thuật toán để giải quyết bài toán (trình bày bằng mã giả/ lưu đồ)**
#     -
#
# 4. **Đánh giá độ phức tạp thuật toán**
